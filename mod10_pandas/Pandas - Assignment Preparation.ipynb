# %% [markdown]
# ## Assignment Preparation

# %% [markdown]
# Pandas provides the `read_csv()` function to read data stored as a csv file into a Pandas `DataFrame`:

# %%
import pandas as pd
titanic = pd.read_csv("titanic.csv")

# %% [markdown]
# Pandas supports many different file formats or data sources (csv, Excel, SQL, JSON, ...), each of them with the prefix `read_*`.
#
# Make sure to always check the data after reading it in. When displaying a `DataFrame`, the first and last 5 rows will be shown by default:

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# To get the first N entries of a `DataFrame`, use the `head()` method with the required number of rows as the argument:

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# Pandas also provides a `tail()` method. `titanic.tail(10)` will return the last 10 rows of the `DataFrame`:

# %%
titanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# The method `info()` provides technical information about a `DataFrame`:

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# The output tells us:
#
# - We have a `DataFrame`
# - There are 891 entries (or rows)
# - Each row has a row label (aka the index) with values ranging from 0 to 890
# - The table has 12 columns
#     - Most columns have a value for each of the rows (all 891 values are non-null)
#     - Some columns do have missing values and less than 891 non-null values
# - The columns `Name`, `Sex`, `Cabin`, and `Embarked` consist of textual data (strings, aka `object`). The other columns are numerical data with some of them whole numbers (aka `int64`) and others are real numbers (aka `float64`)
# - The kind of data in the different columns is summarized by listing the `dtype`s
# - The approximate amount of memory used to hold the `DataFrame` is provided as well
#
# `DataFrame.shape` is an attribute containing the number of rows and columns: `(nrows, ncolumns)`

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.shape[0] # nrows
# Out:
# 891

# %%
titanic.shape[1] # ncolumns
# Out:
# 12

# %% [markdown]
# If we want to calculate a given statistic (e.g., mean, median, sum, min, max) for each category in a column (e.g., male/female in the `Sex` column), we can use the `groupby()` method. This method works by:
#
# 1. Splitting the data into groups
# 2. Applying a function to each group independently
# 3. Combining the results into a data structure
#
# The apply and combine steps are typically done together in Pandas. For example, if we want to calculate the mean for each numerical column in our dataset grouped by `Sex`, we would do the following:

# %%
titanic.groupby("Sex").mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %% [markdown]
# It doesn't make much sense to get the average value of some of our columns, such as `Pclass`. If we are only interested in the average age for each gender, the selection of columns with `[]` is supported as well:

# %%
titanic.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %% [markdown]
# Grouping can be done by multiple columns at the same time, just provide the column names as a list to the `groupby()` method. For example, what is the mean ticket fare price for each of the `Sex` and `Pclass` (cabin class) combinations?

# %%
titanic.groupby(["Sex", "Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
titanic.groupby("Sex")[["Age", "Fare"]].mean()
# Out:
#               Age       Fare
# Sex
# female  27.915709  44.479818
# male    30.726645  25.523893

# %% [markdown]
# We can also sort our data according to a specific column. For example, let's sort the `titanic` data according to the age of the passengers:

# %%
titanic.sort_values(by="Age").head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %% [markdown]
# Or sort the `titanic` data according to the cabin class and age in descending order:

# %%
titanic.sort_values(by=['Pclass','Age'],ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 851          852         0       3        Svensson, Mr. Johan    male  74.0
# 116          117         0       3       Connors, Mr. Patrick    male  70.5
# 280          281         0       3           Duane, Mr. Frank    male  65.0
# 483          484         1       3     Turkula, Mrs. (Hedwig)  female  63.0
# 326          327         0       3  Nysveen, Mr. Johan Hansen    male  61.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 851      0      0  347060  7.7750   NaN        S
# 116      0      0  370369  7.7500   NaN        Q
# 280      0      0  336439  7.7500   NaN        Q
# 483      0      0    4134  9.5875   NaN        S
# 326      0      0  345364  6.2375   NaN        S

# %% [markdown]
# We can count the number of records for each category in a column with the `value_counts()` method. For example: let's get the number of passengers in each of the cabin classes:

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic[["Sex", "Pclass"]].value_counts()
# Out:
# Sex     Pclass
# male    3         347
# female  3         144
# male    1         122
#         2         108
# female  1          94
#         2          76
# dtype: int64

# %% [markdown]
# The function is a shortcut, as it is actually a `groupby()` operation in combination with the counting of the number of records within each group:

# %%
titanic.groupby("Pclass")["Pclass"].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
titanic.groupby(["Sex", "Pclass"])["Pclass"].count()
# Out:
# Sex     Pclass
# female  1          94
#         2          76
#         3         144
# male    1         122
#         2         108
#         3         347
# Name: Pclass, dtype: int64

# %% [markdown]
# To get basic statistics, use the `describe()` method, which provides a quick overview of the numerical data in a `DataFrame`:

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic[["Age", "Fare"]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
titanic["Age"].describe()['mean':'min']
# Out:
# mean    29.699118
# std     14.526497
# min      0.420000
# Name: Age, dtype: float64

# %% [markdown]
# If we wanted to include all columns, not just numerical ones, we could include the optional parameter `include="all"`:

# %%
titanic.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# Instead of the predefined statistics, specific combinations of aggregating statistics for given columns can be defined using the `agg()` method:

# %%
titanic.agg({"Age":['min','max','median','sum'],
             "Fare":['min','max','median','mean']})
# Out:
#              Age        Fare
# min         0.42    0.000000
# max        80.00  512.329200
# median     28.00   14.454200
# sum     21205.17         NaN
# mean         NaN   32.204208

# %% [markdown]
# We can apply functions over rows of data using the `apply()` method.
#
# Syntax: `DataFrame.apply(function)`
#
# For example:

# %%
# create a function
def sex_to_num(x):
    if x == 'male':
        return 1
    if x == 'female':
        return 0

# apply the function to the Sex column and create a new column
titanic['Sex_N'] = titanic["Sex"].apply(sex_to_num)

titanic[["Sex","Sex_N"]].head()
# Out:
#       Sex  Sex_N
# 0    male      1
# 1  female      0
# 2  female      0
# 3  female      0
# 4    male      1

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# If we want to get the index location of a value in a column, we can use the `idxmax()` method. For example, if we wanted to get the passenger with the longest name on the Titanic, we could find its index location by:

# %%
titanic["Name"].str.len().idxmax()
# Out:
# 307

# %% [markdown]
# By using the `str.len()` method, the function is applied to each of the names individually. With this information, we are able to utilize the `loc` operator to determine what the longest name is:

# %%
titanic.loc[titanic["Name"].str.len().idxmax(), "Name"]
# Out:
# 'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %% [markdown]
# We can filter specific rows from a `DataFrame` using our `[]` notation. For example, if we wanted to get all entries where `Age` is greater than 35, we could write:

# %%
titanic[titanic["Age"] > 35].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 6             7         0       1
# 11           12         1       1
# 13           14         0       3
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 13      5    347082  31.2750   NaN        S
# 15      0    248706  16.0000   NaN        S

# %%
titanic["Age"] > 35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %% [markdown]
# To select rows based on a conditional expression, we use a condition inside the `[]`. The condition inside the `[]` `titanic['Age'] > 35` checks for which rows the `Age` column has a value larger than 35.
#
# The output of the conditional expression (>, ==, !=, <, <=, >=, ...) is actually a Pandas `Series` of boolean values (`True` or `False`) with the same number of rows as the original `DataFrame`. Such a `Series` of boolean values can be used to filter the `DataFrame` by putting it in between the `[]`. Only rows for which the value is `True` will be selected.
#
# If we want to combine multiple conditional statements, each condition must be surrounded by parentheses. Moreover, we cannot use `or` or `and`, but we need to use the operators `|` and `&`, respectively:

# %%
titanic[(titanic["Age"] > 35) | (titanic["Fare"] < 600)].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# To select multiple columns, use a list of column names within the `[]`. The inner square brackets define a Python list with column names, whereas the outer brackets are used to select the data from a Pandas `DataFrame`:

# %%
titanic[["Age","Sex"]].head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %% [markdown]
# We can append two `DataFrame`s together using the `append()` method.
#
# Syntax: `DataFrame.append(DataFrame)`
#
# For example, if we wanted to append our area/population `DataFrame` to our Titanic data:

# %%
area = pd.Series({'California': 423967, 'Texas': 695662,
                  'New York': 141297, 'Florida': 170312,
                  'Illinois': 149995})
population = pd.Series({'California': 38332521, 'Texas': 26448193,
                 'New York': 19651127, 'Florida': 19552860,
                 'Illinois': 12882135})
data = pd.DataFrame({'area':area, 'pop':population})
data
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
titanic.append(data)
# Out:
# /var/folders/vy/r2k1d_qd7qq72mp6t471xvq80000gp/T/ipykernel_5842/733124079.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   titanic.append(data)
#             PassengerId  Survived  Pclass  \
# 0                   1.0       0.0     3.0
# 1                   2.0       1.0     1.0
# 2                   3.0       1.0     3.0
# 3                   4.0       1.0     1.0
# 4                   5.0       0.0     3.0
# ...                 ...       ...     ...
# California          NaN       NaN     NaN
# Texas               NaN       NaN     NaN
# New York            NaN       NaN     NaN
# Florida             NaN       NaN     NaN
# Illinois            NaN       NaN     NaN
#
#                                                          Name     Sex   Age  \
# 0                                     Braund, Mr. Owen Harris    male  22.0
# ...

# %% [markdown]
# Additionally, we can use the `concat()` function, which performs concatenation operations of multiple tables along one of the axes (row-wise or column-wise). By default, concatenation is along axis 0, so the resulting table combines the rows of the input tables.
#
# For example, if we wanted to combine our two previous datasets together along the rows:

# %%
pd.concat([titanic, data])
# Out:
#             PassengerId  Survived  Pclass  \
# 0                   1.0       0.0     3.0
# 1                   2.0       1.0     1.0
# 2                   3.0       1.0     3.0
# 3                   4.0       1.0     1.0
# 4                   5.0       0.0     3.0
# ...                 ...       ...     ...
# California          NaN       NaN     NaN
# Texas               NaN       NaN     NaN
# New York            NaN       NaN     NaN
# Florida             NaN       NaN     NaN
# Illinois            NaN       NaN     NaN
#
#                                                          Name     Sex   Age  \
# 0                                     Braund, Mr. Owen Harris    male  22.0
# 1           Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                      Heikkinen, Miss. Laina  female  26.0
# 3                Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# ...

# %% [markdown]
# We can also merge datasets together using the `merge()` function. This differs from the `append()` method and the `concat()` function as the `merge()` function need a common column, which is used as a key to combine the information.
#
# Syntax: `pd.merge(DataFrame1, DataFrame2, how, on)`
#
# Parameters:
#
# - `how`: specifies how to merge; default: `"inner"`
#     - Other options include  `"left"`, `"right"`, and `"outer"`
# - `on`: specifies on what level to do the merging
#
# For example:

# %%
data1 = {"name": ["Sally", "Mary", "John"],
         "age": [50, 40, 30]}

data2 = {"name": ["Sally", "Peter", "Micky"],
         "age": [77, 44, 22]}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

newdf = pd.merge(df1, df2, how='left', on='name')

newdf.head()
# Out:
#     name  age_x  age_y
# 0  Sally     50   77.0
# 1   Mary     40    NaN
# 2   John     30    NaN

# %% [markdown]
# We can rename our row and column labels using the `rename()` method. The argument to pass is a dictionary with the keys as the current names and the values as the new names to update the corresponding names.
#
# For example:

# %%
df2.head()
# Out:
#     name  age
# 0  Sally   77
# 1  Peter   44
# 2  Micky   22

# %%
df2.rename(columns={"name":"Name", "age":"Age"})
# Out:
#     Name  Age
# 0  Sally   77
# 1  Peter   44
# 2  Micky   22

# %% [markdown]
# The function `reset_index()` can be used to convert any level of an index to a column, e.g.,:

# %%
df2.reset_index()
# Out:
#    index   name  age
# 0      0  Sally   77
# 1      1  Peter   44
# 2      2  Micky   22

# %% [markdown]
# We can return all entries without `Null` values with the `notna()` method. It returns a `True` for each row the values are not a `Null` value. As such, this can be combined with `[]` to filter the data table:

# %%
titanic[titanic["Age"].notna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic["Age"].notna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Sex_N        891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB
